# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in /usr/local/lib/python3.11/dist-packages (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography) (2.22)

# %%
from cryptography.fernet import Fernet
# Generate a key
key = Fernet.generate_key()
from cryptography.fernet import Fernet
# Generate a key
key = Fernet.generate_key()
cipher_suite = Fernet(key)

#First name to encrypt
message = b"First name Bizimana" # added b"" to make it bytes

#Encrypt
encrypted_message = cipher_suite.encrypt(message)
print(encrypted_message)

#Decrypt
decrypted_message = cipher_suite.decrypt(encrypted_message)
print(decrypted_message)

#First name to encrypt
message1 = b"Last name Baruani"

#Encrypt
encrypted_message = cipher_suite.encrypt(message1)
print(encrypted_message)

#Decrypt
decrypted_message = cipher_suite.decrypt(encrypted_message)
print(decrypted_message)
# Out:
# b'gAAAAABnrhdirehy5temDXxYs0DkPEPzlQd63WChEs_5Dck-fsgGV75C3YuR_cWr6mRBNCQ69M-5XOz5vq-kyOI-zMAUEUB1foDPdv1l7pTkVWT6VDp9kYM='
# b'First name Bizimana'
# b'gAAAAABnrhdiIHAeEN0jdNMDfYZabiLknJ-4_nRQL6Q-J1ZMxlZohvhLM7kOEzMKeypCdnheqhPU2U7jq9cokR36JH7vfdYg3ZYCL9x4YZ8JTFRLYzK0ODo='
# b'Last name Baruani'
